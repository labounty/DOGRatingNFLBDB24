# %% [markdown]
# # **Train-Validate-Test Split**
# The purpose of this notebook is to randomly sample the entire set of observations (9720) into a 60-10-30 train-validate-test set. Data can be taken from the validate or test and added ot the train if need be. Random sampling will happen on a player by player level taking 60%, 10%, 30% from each specific player

# %% [markdown]
# ## **1.0: Introduction**
# ### **1.1: Data and Module Load**

# %%
import pandas as pd
import numpy as np
import sklearn
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
feature_set_whole = pd.read_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Processed/tackles_feature_set_1.csv')

# %%
feature_set_whole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9720 entries, 0 to 9719
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gameId            9720 non-null   int64
#  1   playId            9720 non-null   int64
#  2   nflId             9720 non-null   int64
#  3   tackle            9720 non-null   int64
#  4   assist            9720 non-null   int64
#  5   forcedFumble      9720 non-null   int64
#  6   pff_missedTackle  9720 non-null   int64
#  7   game_play_Id      9720 non-null   object
#  8   event_type        9720 non-null   float64
#  9   s_avg_05          9720 non-null   float64
#  10  s_avg_1           9720 non-null   float64
#  11  bc_s_avg_05       9720 non-null   float64
#  12  bc_s_avg_1        9720 non-null   float64
#  13  cos_avg_05        9720 non-null   float64
#  14  cos_avg_1         9720 non-null   float64
#  15  do_avg_05         9720 non-null   float64
#  16  do_avg_1          9720 non-null   float64
#  17  bc_do_avg_05      9720 non-null   float64
#  18  bc_do_avg_1       9720 non-null   float64
#  19  cos_05_null       9720 non-null   int64
#  20  cos_1_null        9720 non-null   int64
#  21  ballCarrierId     9720 non-null   int64
# dtypes: float64(11), int64(10), object(1)
# memory usage: 1.6+ MB

# %%
pd.set_option('display.max_columns', None)
feature_set_whole.head(50)
# Out:
#         gameId  playId  nflId  tackle  assist  forcedFumble  pff_missedTackle  \
# 0   2022090800     101  42816       1       0             0                 0
# 1   2022090800     393  46232       1       0             0                 0
# 2   2022090800     486  40166       1       0             0                 0
# 3   2022090800     646  47939       1       0             0                 0
# 4   2022090800     818  40107       1       0             0                 0
# 5   2022090800    1736  44976       1       0             0                 0
# 6   2022090800    2860  46085       1       0             0                 0
# 7   2022090800    3145  52647       1       0             0                 0
# 8   2022090800    3362  46190       1       0             0                 0
# 9   2022090800    3383  54488       1       0             0                 0
# 10  2022091100    1260  44851       1       0             0                 0
# 11  2022091100    1672  40017       1       0             0                 0
# 12  2022091100    2114  53469       1       0             0                 0
# 13  2022091100    2353  38607       1       0             0                 0
# 14  2022091100    2512  53611       1       0             0                 0
# 15  2022091100    2640  44862       1       0             0                 0
# 16  2022091100    2878  53489       1       0             0                 0
# 17  2022091100    2899  37097       1       0             0                 0
# 18  2022091100    3578  52542       1       0             0                 0
# 19  2022091100    3647  53469       1       0             0                 0
# 20  2022091100    3778  53489       1       0             0                 0
# 21  2022091101    1744  44903       1       0             0                 0
# 22  2022091101    1785  52452       1       0             0                 0
# 23  2022091101    2051  46527       1       0             0                 0
# 24  2022091101    3221  47799       1       0             0                 0
# 25  2022091102      86  44938       1       0             0                 0
# 26  2022091102     531  52571       1       0             0                 0
# 27  2022091102     756  53609       1       0             0                 0
# 28  2022091102    1493  54504       1       0             0                 0
# 29  2022091102    2065  54504       1       0             0                 0
# 30  2022091102    2352  46290       1       0             0                 0
# 31  2022091102    2759  54504       1       0             0                 0
# 32  2022091102    3783  52571       1       0             0                 0
# 33  2022091103     520  46146       1       0             0                 0
# 34  2022091103    1037  44842       1       0             0                 0
# 35  2022091103    1315  46080       1       0             0                 0
# 36  2022091103    2058  43641       1       0             0                 0
# 37  2022091103    2222  44842       1       0             0                 0
# 38  2022091103    2291  46698       1       0             0                 0
# 39  2022091103    3147  44872       1       0             0                 0
# 40  2022091103    3251  43325       1       0             0                 0
# 41  2022091103    4175  43641       1       0             0                 0
# 42  2022091103    4686  43641       1       0             0                 0
# 43  2022091103    5096  43350       1       0             0                 0
# 44  2022091104     803  52411       1       0             0                 0
# 45  2022091104     910  54653       1       0             0                 0
# 46  2022091104     999  47900       1       0             0                 0
# 47  2022091104    2269  44888       1       0             0                 0
# 48  2022091104    2974  47888       1       0             0                 0
# 49  2022091104    3172  46151       1       0             0                 0
#
#        game_play_Id  event_type  s_avg_05  s_avg_1  bc_s_avg_05  bc_s_avg_1  \
# 0    2022090800_101         1.0     3.520    4.332        5.694       6.830
# 1    2022090800_393         1.0     2.164    1.706        0.298       0.336
# 2    2022090800_486         1.0     2.332    2.274        3.000       2.376
# 3    2022090800_646         1.0     4.274    5.334        4.364       5.720
# 4    2022090800_818         1.0     0.854    1.828        1.448       2.134
# 5   2022090800_1736         1.0     4.794    4.612        4.398       4.650
# 6   2022090800_2860         1.0     2.492    3.170        3.390       2.560
# 7   2022090800_3145         1.0     2.526    1.584        2.538       1.270
# 8   2022090800_3362         1.0     4.638    4.050        3.230       4.426
# 9   2022090800_3383         1.0     2.106    1.668        2.210       1.382
# 10  2022091100_1260         1.0     2.902    1.642        2.310       2.932
# 11  2022091100_1672         1.0     0.960    1.038        2.860       3.044
# 12  2022091100_2114         1.0     1.316    2.822        5.148       5.182
# 13  2022091100_2353         1.0     2.890    4.766        3.414       5.610
# 14  2022091100_2512         1.0     3.668    5.268        4.740       5.790
# 15  2022091100_2640         1.0     5.946    6.110        6.082       6.304
# 16  2022091100_2878         1.0     0.502    1.124        3.116       4.014
# 17  2022091100_2899         1.0     1.500    2.290        0.862       2.028
# 18  2022091100_3578         1.0     2.658    4.704        3.582       4.726
# 19  2022091100_3647         1.0     4.054    6.274        4.998       5.004
# 20  2022091100_3778         1.0     3.454    2.788        5.276       6.660
# 21  2022091101_1744         1.0     7.414    8.906        7.630       8.338
# 22  2022091101_1785         1.0     3.094    5.422        3.904       4.632
# 23  2022091101_2051         1.0     0.292    0.648        0.032       0.108
# 24  2022091101_3221         1.0     4.474    5.642        3.724       4.846
# 25    2022091102_86         1.0     2.062    3.594        1.536       3.046
# 26   2022091102_531         1.0     3.084    3.980        3.708       3.788
# 27   2022091102_756         1.0     4.496    6.692        4.660       5.526
# 28  2022091102_1493         1.0     2.088    1.648        1.148       3.446
# 29  2022091102_2065         1.0     2.056    4.714        2.218       4.728
# 30  2022091102_2352         1.0     0.124    0.860        0.352       0.396
# 31  2022091102_2759         1.0     3.940    5.270        3.716       4.262
# 32  2022091102_3783         1.0     0.250    0.772        1.494       2.672
# 33   2022091103_520         1.0     1.510    0.998        1.662       1.076
# 34  2022091103_1037         1.0     3.026    4.382        1.056       2.782
# 35  2022091103_1315         1.0     2.020    1.500        2.050       3.484
# 36  2022091103_2058         1.0     1.122    2.826        1.264       0.930
# 37  2022091103_2222         1.0     3.046    4.372        3.586       5.572
# 38  2022091103_2291         1.0     1.376    1.352        2.654       2.768
# 39  2022091103_3147         1.0     4.480    4.094        2.990       3.016
# 40  2022091103_3251         1.0     6.884    8.052        5.982       7.932
# 41  2022091103_4175         1.0     3.558    5.690        2.948       3.982
# 42  2022091103_4686         1.0     2.050    3.198        2.664       1.996
# 43  2022091103_5096         1.0     4.590    6.072        4.024       5.432
# 44   2022091104_803         1.0     2.802    2.338        4.440       5.360
# 45   2022091104_910         1.0     0.628    0.256        1.742       0.746
# 46   2022091104_999         1.0     5.044    4.202        5.562       6.430
# 47  2022091104_2269         1.0     6.482    8.430        5.112       8.216
# 48  2022091104_2974         1.0     3.124    3.642        3.986       5.592
# 49  2022091104_3172         1.0     2.446    1.894        7.652       7.812
#
#     cos_avg_05  cos_avg_1  do_avg_05  do_avg_1  bc_do_avg_05  bc_do_avg_1  \
# 0     0.428826  -0.385109   0.832711  0.645022      0.691600     0.929311
# 1     0.985862   0.787554   0.287244  0.604378     -0.093511    -0.303400
# 2     0.995057   0.993806  -0.236111  0.522356     -0.263867     0.533244
# 3     0.975704   0.987113   0.287667  0.059622     -0.590022     0.458689
# 4     0.191356   0.563645   0.215956  0.442644     -0.301644    -0.653667
# 5     0.124383  -0.728045   0.702711  0.598533      0.302244     0.916533
# 6     0.760174  -0.071476   0.523244  0.854733      0.882800     0.675067
# 7     0.758493   0.166756   0.320667  0.658911     -0.696578    -0.292800
# 8    -0.812444  -0.984762   0.184089  0.618489      0.726556     0.890378
# 9     0.992764   0.930209   0.496000  0.318089     -0.221467    -0.341511
# 10    0.790750   0.484533   0.729844  0.146711     -0.715000    -0.167156
# 11    0.915242  -0.096464   0.608400  0.309867     -0.007578     0.594756
# 12   -0.407532  -0.678775  -0.418956  0.450756      0.754578     0.831822
# 13    0.978972   0.853606  -0.870222 -0.302600      0.879044     0.899533
# 14    0.974194   0.954641   0.480378  0.846778      0.623756     0.738578
# 15    0.800958   0.564771   0.906733  0.643556      0.976089     0.777178
# 16    0.693378   0.037677  -0.219422  0.507222      0.453711     0.772089
# 17    0.929083   0.920706   0.230644  0.333867      0.402289     0.715533
# 18   -0.977228  -0.849411   0.444867  0.676778     -0.260978     0.279378
# 19    0.985257   0.905291   0.806444  0.717578      0.221978     0.148511
# 20    0.810879   0.451718   0.802089  0.677244      0.577000     0.711689
# 21    0.962508   0.961765   0.625822  0.177800      0.309333     0.350378
# 22    0.510761   0.455433   0.839822  0.926867      0.037067    -0.790178
# 23    0.941067   0.958682   0.546933  0.461311     -0.555533    -0.310800
# 24    0.991906   0.923827  -0.300133  0.384267      0.532467     0.746378
# 25    0.915136   0.942995   0.443511 -0.024822      0.749467     0.561556
# 26    0.993932   0.985377   0.073933  0.329978     -0.858622    -0.669778
# 27    0.444850   0.218954   0.838311  0.881578      0.791400     0.754711
# 28    0.801562   0.356093   0.247644  0.770689      0.666889     0.934822
# 29    0.957730   0.998227  -0.244222  0.079178     -0.778244    -0.810444
# 30   -0.733261   0.117233   0.487667  0.899444      0.493644     0.127578
# 31    0.985712   0.896576   0.387311  0.348133      0.310533     0.553222
# 32   -0.165863  -0.920424   0.344622  0.718778      0.224733    -0.192333
# 33    0.927395   0.842191   0.065378  0.559200     -0.569867     0.693489
# 34    0.470649  -0.927726  -0.258067  0.799089     -0.444111     0.626778
# 35    0.844278  -0.569803  -0.729156 -0.550333     -0.389800     0.533333
# 36    0.954887   0.886119  -0.534778  0.222756      0.601578     0.630333
# 37    0.965273   0.764376   0.953622  0.733800      0.357933     0.735467
# 38    0.983289   0.987004   0.571822  0.009222     -0.503156    -0.702978
# 39    0.946720   0.973165   0.383756  0.716000      0.894489     0.475333
# 40    0.975881   0.961501   0.882800  0.703356      0.260511     0.760222
# 41    0.986116   0.988007   0.379822  0.484689      0.116889     0.564978
# 42    0.531635  -0.744747   0.093822  0.852733     -0.365311    -0.039644
# 43    0.983611   0.913662   0.457400  0.889267      0.753467     0.874533
# 44    0.970540   0.752486   0.956267 -0.002467     -0.388533     0.664578
# 45    0.961427   0.989477   0.028822 -0.313933      0.883800     0.115067
# 46    0.901794   0.890944   0.959400  0.861844      0.825133     0.793000
# 47    0.985115   0.991495  -0.489200  0.858711     -0.123378     0.152822
# 48    0.969970   0.744959   0.876333  0.710578      0.784622     0.794178
# 49   -0.954416  -0.117976   0.617889 -0.364800      0.864111     0.791911
#
#     cos_05_null  cos_1_null  ballCarrierId
# 0             0           0          47857
# 1             0           0          47853
# 2             0           0          44881
# 3             0           0          47879
# 4             0           0          47853
# 5             0           0          52460
# 6             0           0          44881
# 7             0           0          47853
# 8             0           0          47853
# 9             0           0          44881
# 10            0           0          39975
# 11            0           0          39975
# 12            0           0          45244
# 13            0           0          39975
# 14            0           0          45244
# 15            0           0          42345
# 16            0           0          53612
# 17            0           0          53612
# 18            0           0          43336
# 19            0           0          41292
# 20            0           0          39975
# 21            0           0          46170
# 22            0           0          53512
# 23            0           0          46104
# 24            0           0          46104
# 25            0           0          47856
# 26            0           0          53623
# 27            0           0          53646
# 28            0           0          47819
# 29            0           0          47819
# 30            0           0          46377
# 31            0           0          52625
# 32            0           0          52625
# 33            0           0          53453
# 34            0           0          44860
# 35            0           0          44860
# 36            0           0          52457
# 37            0           0          44927
# 38            0           0          53434
# 39            0           0          54517
# 40            0           0          52409
# 41            0           0          53484
# 42            0           0          52457
# 43            0           0          53484
# 44            0           0          47836
# 45            0           0          53579
# 46            0           0          47836
# 47            0           0          47836
# 48            0           0          52443
# 49            0           0          52461

# %% [markdown]
# ## **2.0: Feature Set Exploration**

# %% [markdown]
# ### **2.1: Checking Prevalence of Players in Feature Set**

# %%
feature_set_whole.nflId.nunique()
# Out:
# 760

# %%
feature_set_whole.ballCarrierId.nunique()
# Out:
# 464

# %%
feature_set_whole.nflId.value_counts()
# Out:
# nflId
# 46269    63
# 46304    61
# 52435    59
# 41243    56
# 47913    51
#          ..
# 53053     1
# 52535     1
# 54705     1
# 54665     1
# 53531     1
# Name: count, Length: 760, dtype: int64

# %%
nflIds = feature_set_whole.nflId.value_counts()

# %%
count = sum(nflIds > 27)
print(count)
# Out:
# 94

# %%
feature_set_whole.ballCarrierId.value_counts()
# Out:
# ballCarrierId
# 43334    186
# 47807    168
# 54572    168
# 46071    158
# 46104    154
#         ...
# 43496      1
# 48657      1
# 37118      1
# 48576      1
# 54663      1
# Name: count, Length: 464, dtype: int64

# %% [markdown]
# ## **3.0: Splitting Data**

# %% [markdown]
# ### **3.1: Adding Target Label: Tackle_Status**

# %%
feature_set_whole['tackle_status'] = feature_set_whole['event_type'].apply(lambda x: 1 if x in [1, 3] else 0 if x in [2, 4] else np.nan)

# %%
feature_set_whole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9720 entries, 0 to 9719
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gameId            9720 non-null   int64
#  1   playId            9720 non-null   int64
#  2   nflId             9720 non-null   int64
#  3   tackle            9720 non-null   int64
#  4   assist            9720 non-null   int64
#  5   forcedFumble      9720 non-null   int64
#  6   pff_missedTackle  9720 non-null   int64
#  7   game_play_Id      9720 non-null   object
#  8   event_type        9720 non-null   float64
#  9   s_avg_05          9720 non-null   float64
#  10  s_avg_1           9720 non-null   float64
#  11  bc_s_avg_05       9720 non-null   float64
#  12  bc_s_avg_1        9720 non-null   float64
#  13  cos_avg_05        9720 non-null   float64
#  14  cos_avg_1         9720 non-null   float64
#  15  do_avg_05         9720 non-null   float64
#  16  do_avg_1          9720 non-null   float64
#  17  bc_do_avg_05      9720 non-null   float64
#  18  bc_do_avg_1       9720 non-null   float64
#  19  cos_05_null       9720 non-null   int64
#  20  cos_1_null        9720 non-null   int64
#  21  ballCarrierId     9720 non-null   int64
#  22  tackle_status     9720 non-null   int64
# dtypes: float64(11), int64(11), object(1)
# memory usage: 1.7+ MB

# %%
feature_set_whole.tackle_status.value_counts()
# Out:
# tackle_status
# 1    7834
# 0    1886
# Name: count, dtype: int64

# %%
feature_set_whole.event_type.value_counts()
# Out:
# event_type
# 1.0    7775
# 2.0    1859
# 3.0      59
# 4.0      27
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### **3.2: Creating 60-10-30 Split**

# %%
# Set the random seed for reproducibility
np.random.seed(13)

# Create an empty DataFrame for each set
train = pd.DataFrame()
validation = pd.DataFrame()
test = pd.DataFrame()

# Group the data by 'nflId'
groups = feature_set_whole.groupby('nflId')

# For each group, randomly sample 30% of the data for the test set, 10% for the validation set, and the rest for the training set
for name, group in groups:
    total = group.shape[0]
    test_size = round(total * 0.3)
    validation_size = round(total * 0.1)
    train_size = total - test_size - validation_size
    
    test_group = group.sample(n=test_size)
    remaining_group = group.drop(test_group.index)
    
    validation_group = remaining_group.sample(n=validation_size)
    remaining_group = remaining_group.drop(validation_group.index)
    
    train_group = remaining_group.sample(n=train_size)
    
    test = pd.concat([test, test_group])
    validation = pd.concat([validation, validation_group])
    train = pd.concat([train, train_group])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2917 entries, 3956 to 1872
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gameId            2917 non-null   int64
#  1   playId            2917 non-null   int64
#  2   nflId             2917 non-null   int64
#  3   tackle            2917 non-null   int64
#  4   assist            2917 non-null   int64
#  5   forcedFumble      2917 non-null   int64
#  6   pff_missedTackle  2917 non-null   int64
#  7   game_play_Id      2917 non-null   object
#  8   event_type        2917 non-null   float64
#  9   s_avg_05          2917 non-null   float64
#  10  s_avg_1           2917 non-null   float64
#  11  bc_s_avg_05       2917 non-null   float64
#  12  bc_s_avg_1        2917 non-null   float64
#  13  cos_avg_05        2917 non-null   float64
#  14  cos_avg_1         2917 non-null   float64
#  15  do_avg_05         2917 non-null   float64
#  16  do_avg_1          2917 non-null   float64
#  17  bc_do_avg_05      2917 non-null   float64
#  18  bc_do_avg_1       2917 non-null   float64
#  19  cos_05_null       2917 non-null   int64
#  20  cos_1_null        2917 non-null   int64
#  21  ballCarrierId     2917 non-null   int64
#  22  tackle_status     2917 non-null   int64
# dtypes: float64(11), int64(11), object(1)
# memory usage: 546.9+ KB

# %% [markdown]
# ### **3.3: Data Exploration of the Split Groups**

# %% [markdown]
# #### **3.3.0: Entire Feature Set**

# %%
feature_set_whole.tackle_status.value_counts(normalize=True)*100
# Out:
# tackle_status
# 1    80.596708
# 0    19.403292
# Name: proportion, dtype: float64

# %%
###Checking number of Fred Warner observations in each set
feature_set_whole['nflId'].value_counts()[46139]
# Out:
# 31

# %%
###Checking number of Joe Mixon observations in each set
feature_set_whole['ballCarrierId'].value_counts()[44860]
# Out:
# 140

# %%
###Checking the number of Rashaad Penny observations in each set
feature_set_whole['ballCarrierId'].value_counts()[46096]
# Out:
# 53

# %% [markdown]
# #### **3.3.1: Train**

# %%
train.tackle_status.value_counts()
# Out:
# tackle_status
# 1    4746
# 0    1110
# Name: count, dtype: int64

# %%
train.tackle_status.value_counts(normalize=True) * 100
# Out:
# tackle_status
# 1    81.045082
# 0    18.954918
# Name: proportion, dtype: float64

# %%
###Checking number of Fred Warner observations in each set
train['nflId'].value_counts()[46139]
# Out:
# 19

# %%
###Checking number of Joe Mixon observations in each set
train['ballCarrierId'].value_counts()[44860]
# Out:
# 78

# %%
###Checking the number of Rashaad Penny observations in each set
train['ballCarrierId'].value_counts()[46096]
# Out:
# 31

# %% [markdown]
# #### **3.3.2: Validation**

# %%
validation.tackle_status.value_counts(normalize=True) * 100
# Out:
# tackle_status
# 1    77.930306
# 0    22.069694
# Name: proportion, dtype: float64

# %%
###Checking number of Fred Warner observations in each set
validation['nflId'].value_counts()[46139]
# Out:
# 3

# %%
###Checking number of Joe Mixon observations in each set
validation['ballCarrierId'].value_counts()[44860]
# Out:
# 8

# %%
###Checking the number of Rashaad Penny observations in each set
validation['ballCarrierId'].value_counts()[46096]
# Out:
# 5

# %% [markdown]
# #### **3.3: Test**

# %%
test.tackle_status.value_counts()
# Out:
# tackle_status
# 1    2350
# 0     567
# Name: count, dtype: int64

# %%
test.tackle_status.value_counts(normalize=True) * 100
# Out:
# tackle_status
# 1    80.562221
# 0    19.437779
# Name: proportion, dtype: float64

# %%
###Checking number of Fred Warner observations in each set
test['nflId'].value_counts()[46139]
# Out:
# 9

# %%
###Checking number of Joe Mixon observations in each set
test['ballCarrierId'].value_counts()[44860]
# Out:
# 54

# %%
###Checking the number of Rashaad Penny observations in each set
test['ballCarrierId'].value_counts()[46096]
# Out:
# 17

# %% [markdown]
# ## **4.0: Saving DFs for Modeling**

# %% [markdown]
# ### **4.1: Train**

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5856 entries, 8593 to 1708
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gameId            5856 non-null   int64
#  1   playId            5856 non-null   int64
#  2   nflId             5856 non-null   int64
#  3   tackle            5856 non-null   int64
#  4   assist            5856 non-null   int64
#  5   forcedFumble      5856 non-null   int64
#  6   pff_missedTackle  5856 non-null   int64
#  7   game_play_Id      5856 non-null   object
#  8   event_type        5856 non-null   float64
#  9   s_avg_05          5856 non-null   float64
#  10  s_avg_1           5856 non-null   float64
#  11  bc_s_avg_05       5856 non-null   float64
#  12  bc_s_avg_1        5856 non-null   float64
#  13  cos_avg_05        5856 non-null   float64
#  14  cos_avg_1         5856 non-null   float64
#  15  do_avg_05         5856 non-null   float64
#  16  do_avg_1          5856 non-null   float64
#  17  bc_do_avg_05      5856 non-null   float64
#  18  bc_do_avg_1       5856 non-null   float64
#  19  cos_05_null       5856 non-null   int64
#  20  cos_1_null        5856 non-null   int64
#  21  ballCarrierId     5856 non-null   int64
#  22  tackle_status     5856 non-null   int64
# dtypes: float64(11), int64(11), object(1)
# memory usage: 1.1+ MB

# %%
train_target = train['tackle_status']

# %%
train_features = train.drop(['tackle_status', 'event_type', 'nflId', 'ballCarrierId', 'gameId', 'playId', 'game_play_Id', 'tackle', 'assist', 'forcedFumble', 'pff_missedTackle'], axis=1)

# %%
train.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Processed/train.csv', index=False)

# %%
train_target.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Modeling_Data/train_target.csv', index=False)

# %%
train_features.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Modeling_Data/train_features.csv', index=False)

# %% [markdown]
# ### **4.2: Validation**

# %%
validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 1923 to 2632
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gameId            947 non-null    int64
#  1   playId            947 non-null    int64
#  2   nflId             947 non-null    int64
#  3   tackle            947 non-null    int64
#  4   assist            947 non-null    int64
#  5   forcedFumble      947 non-null    int64
#  6   pff_missedTackle  947 non-null    int64
#  7   game_play_Id      947 non-null    object
#  8   event_type        947 non-null    float64
#  9   s_avg_05          947 non-null    float64
#  10  s_avg_1           947 non-null    float64
#  11  bc_s_avg_05       947 non-null    float64
#  12  bc_s_avg_1        947 non-null    float64
#  13  cos_avg_05        947 non-null    float64
#  14  cos_avg_1         947 non-null    float64
#  15  do_avg_05         947 non-null    float64
#  16  do_avg_1          947 non-null    float64
#  17  bc_do_avg_05      947 non-null    float64
#  18  bc_do_avg_1       947 non-null    float64
#  19  cos_05_null       947 non-null    int64
#  20  cos_1_null        947 non-null    int64
#  21  ballCarrierId     947 non-null    int64
#  22  tackle_status     947 non-null    int64
# dtypes: float64(11), int64(11), object(1)
# memory usage: 177.6+ KB

# %%
validation_target = validation['tackle_status']

# %%
validation_features = validation.drop(['tackle_status', 'event_type', 'nflId', 'ballCarrierId', 'gameId', 'playId', 'game_play_Id', 'tackle', 'assist', 'forcedFumble', 'pff_missedTackle'], axis=1)

# %%
validation.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Processed/validation.csv', index=False)

# %%
validation_target.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Modeling_Data/validation_target.csv', index=False)

# %%
validation_features.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Modeling_Data/validation_features.csv', index=False)

# %% [markdown]
# ### **4.3: Test**

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2917 entries, 3956 to 1872
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gameId            2917 non-null   int64
#  1   playId            2917 non-null   int64
#  2   nflId             2917 non-null   int64
#  3   tackle            2917 non-null   int64
#  4   assist            2917 non-null   int64
#  5   forcedFumble      2917 non-null   int64
#  6   pff_missedTackle  2917 non-null   int64
#  7   game_play_Id      2917 non-null   object
#  8   event_type        2917 non-null   float64
#  9   s_avg_05          2917 non-null   float64
#  10  s_avg_1           2917 non-null   float64
#  11  bc_s_avg_05       2917 non-null   float64
#  12  bc_s_avg_1        2917 non-null   float64
#  13  cos_avg_05        2917 non-null   float64
#  14  cos_avg_1         2917 non-null   float64
#  15  do_avg_05         2917 non-null   float64
#  16  do_avg_1          2917 non-null   float64
#  17  bc_do_avg_05      2917 non-null   float64
#  18  bc_do_avg_1       2917 non-null   float64
#  19  cos_05_null       2917 non-null   int64
#  20  cos_1_null        2917 non-null   int64
#  21  ballCarrierId     2917 non-null   int64
#  22  tackle_status     2917 non-null   int64
# dtypes: float64(11), int64(11), object(1)
# memory usage: 546.9+ KB

# %%
test_target = test['tackle_status']

# %%
test_features = test.drop(['tackle_status', 'event_type', 'gameId', 'playId', 'game_play_Id', 'tackle', 'assist', 'forcedFumble', 'pff_missedTackle'], axis=1)

# %%
test.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Processed/test.csv', index=False)

# %%
test_target.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Modeling_Data/test_target.csv', index=False)

# %%
test_features.to_csv('/Users/alexiainman/Documents/Big Data Bowl/Data/Modeling_Data/test_features.csv', index=False)
